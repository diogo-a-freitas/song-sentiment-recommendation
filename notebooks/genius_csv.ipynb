# %%
import pandas as pd

#genius = pd.read_csv('raw_data/song_lyrics.csv', skiprows=range(1, 5_000_001), nrows=1_000_000)

# %%
first_million = pd.read_csv('raw_data/new_songs_first_1m.csv')

# %% [markdown]
# # clean data

# %%
import re
import string
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from textblob import TextBlob
import unicodedata


def preprocessing(sentence):
        
    sentence = sentence.strip()
    
    # Convert to lowercase
    sentence = sentence.lower()
    
    # Replace newline characters with space
    sentence = sentence.replace("\n", " ")
    
    # Remove text within brackets and the brackets themselves
    sentence = re.sub(r'\[.*?\]', '', sentence)
    
    # Remove single quotes
    sentence = sentence.replace("\'", "")
    
    # Remove numbers
    sentence = re.sub(r'\b\d+\b', '', sentence)
    
    # Remove punctuation
    sentence = ''.join(char for char in sentence if char not in string.punctuation)
    
    # Remove extra spaces
    sentence = re.sub(r'\s+', ' ', sentence).strip()
    
    # Tokenize sentence
    tokens = word_tokenize(sentence)
    
    # Remove punctuation from tokens
    filtered_tokens = [word for word in tokens if word.isalpha()]
    
    # Lemmatize the tokens
    wnl = WordNetLemmatizer()
    lemmatized_words = [wnl.lemmatize(word, pos='v') for word in filtered_tokens]
    lemmatized_words = [wnl.lemmatize(word, pos='n') for word in lemmatized_words]
    
    return lemmatized_words

# %%
def apply_cleaning_in_batches(df, clean_func, batch_size=100):
    """
    Apply a cleaning function to a DataFrame in batches.
    
    Args:
        df (pd.DataFrame): The input DataFrame containing a column to be cleaned.
        clean_func (function): The cleaning function to apply.
        batch_size (int): Number of rows to process in each batch.

    Returns:
        pd.DataFrame: The DataFrame with the cleaned data.
    """
    # Initialize a list to hold processed batches
    processed_chunks = []

    # Calculate number of batches
    num_batches = (len(df) + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, len(df))
        
        # Extract the current batch
        batch = df.iloc[start_idx:end_idx].copy()
        
        # Apply the cleaning function to the 'lyrics' column
        batch['clean_text'] = batch['lyrics'].apply(clean_func)
        
        # Append processed batch to the list
        processed_chunks.append(batch)
        
        # Print progress
        print(f"✅ Batch {i + 1}/{num_batches} processed ({batch.shape[0]} rows)")

    # Concatenate all processed chunks
    full_data = pd.concat(processed_chunks, ignore_index=True)
    
    print("🥳 All batches processed.")
    return full_data

# %%
first_million_clean = apply_cleaning_in_batches(first_million, preprocessing, batch_size=10_000)
# Out:
# ✅ Batch 1/78 processed (10000 rows)
# ✅ Batch 2/78 processed (10000 rows)
# ✅ Batch 3/78 processed (10000 rows)
# ✅ Batch 4/78 processed (10000 rows)
# ✅ Batch 5/78 processed (10000 rows)
# ✅ Batch 6/78 processed (10000 rows)
# ✅ Batch 7/78 processed (10000 rows)
# ✅ Batch 8/78 processed (10000 rows)
# ✅ Batch 9/78 processed (10000 rows)
# ✅ Batch 10/78 processed (10000 rows)
# ✅ Batch 11/78 processed (10000 rows)
# ✅ Batch 12/78 processed (10000 rows)
# ✅ Batch 13/78 processed (10000 rows)
# ✅ Batch 14/78 processed (10000 rows)
# ✅ Batch 15/78 processed (10000 rows)
# ✅ Batch 16/78 processed (10000 rows)
# ✅ Batch 17/78 processed (10000 rows)
# ✅ Batch 18/78 processed (10000 rows)
# ✅ Batch 19/78 processed (10000 rows)
# ✅ Batch 20/78 processed (10000 rows)
# ✅ Batch 21/78 processed (10000 rows)
# ✅ Batch 22/78 processed (10000 rows)
# ✅ Batch 23/78 processed (10000 rows)
# ✅ Batch 24/78 processed (10000 rows)
# ✅ Batch 25/78 processed (10000 rows)
# ✅ Batch 26/78 processed (10000 rows)
# ✅ Batch 27/78 processed (10000 rows)
# ✅ Batch 28/78 processed (10000 rows)
# ✅ Batch 29/78 processed (10000 rows)
# ✅ Batch 30/78 processed (10000 rows)
# ✅ Batch 31/78 processed (10000 rows)
# ✅ Batch 32/78 processed (10000 rows)
# ✅ Batch 33/78 processed (10000 rows)
# ✅ Batch 34/78 processed (10000 rows)
# ✅ Batch 35/78 processed (10000 rows)
# ✅ Batch 36/78 processed (10000 rows)
# ✅ Batch 37/78 processed (10000 rows)
# ✅ Batch 38/78 processed (10000 rows)
# ✅ Batch 39/78 processed (10000 rows)
# ✅ Batch 40/78 processed (10000 rows)
# ✅ Batch 41/78 processed (10000 rows)
# ✅ Batch 42/78 processed (10000 rows)
# ✅ Batch 43/78 processed (10000 rows)
# ✅ Batch 44/78 processed (10000 rows)
# ✅ Batch 45/78 processed (10000 rows)
# ✅ Batch 46/78 processed (10000 rows)
# ✅ Batch 47/78 processed (10000 rows)
# ✅ Batch 48/78 processed (10000 rows)
# ✅ Batch 49/78 processed (10000 rows)
# ✅ Batch 50/78 processed (10000 rows)
# ✅ Batch 51/78 processed (10000 rows)
# ✅ Batch 52/78 processed (10000 rows)
# ✅ Batch 53/78 processed (10000 rows)
# ✅ Batch 54/78 processed (10000 rows)
# ✅ Batch 55/78 processed (10000 rows)
# ✅ Batch 56/78 processed (10000 rows)
# ✅ Batch 57/78 processed (10000 rows)
# ✅ Batch 58/78 processed (10000 rows)
# ✅ Batch 59/78 processed (10000 rows)
# ✅ Batch 60/78 processed (10000 rows)
# ✅ Batch 61/78 processed (10000 rows)
# ✅ Batch 62/78 processed (10000 rows)
# ✅ Batch 63/78 processed (10000 rows)
# ✅ Batch 64/78 processed (10000 rows)
# ✅ Batch 65/78 processed (10000 rows)
# ✅ Batch 66/78 processed (10000 rows)
# ✅ Batch 67/78 processed (10000 rows)
# ✅ Batch 68/78 processed (10000 rows)
# ✅ Batch 69/78 processed (10000 rows)
# ✅ Batch 70/78 processed (10000 rows)
# ✅ Batch 71/78 processed (10000 rows)
# ✅ Batch 72/78 processed (10000 rows)
# ✅ Batch 73/78 processed (10000 rows)
# ✅ Batch 74/78 processed (10000 rows)
# ✅ Batch 75/78 processed (10000 rows)
# ✅ Batch 76/78 processed (10000 rows)
# ✅ Batch 77/78 processed (10000 rows)
# ✅ Batch 78/78 processed (9759 rows)
# 🥳 All batches processed.

# %%
type(first_million_clean['clean_text'][0])
# Out:
# list

# %% [markdown]
# ## 1ST INTERMEDIARY SAVE TO FEATHER

# %%
import pickle

# Export Pipeline as pickle file
with open("raw_data/first_million_clean.pkl", "wb") as file:
    pickle.dump(first_million_clean, file)

# %%
#load lda model from picklefile // model was already trained on all twitter data and data is static
#with open('raw_data/first_million_clean.pkl', 'rb') as pickle_file:
 #   pickle_first_million_clean = pickle.load(pickle_file)

# %%
# !pip install pyarrow
# Out:
# Requirement already satisfied: pyarrow in /Users/diogofreitas/.pyenv/versions/3.10.6/envs/song-sentiment-recommendation/lib/python3.10/site-packages (17.0.0)
# Requirement already satisfied: numpy>=1.16.6 in /Users/diogofreitas/.pyenv/versions/3.10.6/envs/song-sentiment-recommendation/lib/python3.10/site-packages (from pyarrow) (1.26.4)

# %%
import pyarrow.feather as feather

feather.write_feather(first_million_clean, 'data.feather')

# %%
import pyarrow.feather as feather

first_million_clean = feather.read_feather('data.feather')

# %%
first_million_clean['clean_text'] = list(first_million_clean['clean_text'])

# %%
first_million_clean
# Out:
#                                                     title              artist  \
# 0                                               Killa Cam             Cam'ron
# 1                                              Can I Live               JAY-Z
# 2                                       Forgive Me Father            Fabolous
# 3                                            Down and Out             Cam'ron
# 4                                                  Fly In           Lil Wayne
# ...                                                   ...                 ...
# 779754  The Ballad of Sweeney Todd: “Lift Your Razor H...    Stephen Sondheim
# 779755                                      Progress live         Knife Fight
# 779756                                   Dont Come For Me            Ari Gold
# 779757                        Benton Harbor Blues reprise  The Fiery Furnaces
# 779758                                           Solitude      Jerry Cantrell
#
#         year                                             lyrics language_cld3  \
# 0       2004  [Chorus: Opera Steve & Cam'ron] Killa Cam, Kil...            en
# 1       1996  [Produced by Irv Gotti] [Intro] Yeah, hah, yea...            en
# 2       2003  Maybe cause I'm eatin And these bastards fiend...            en
# 3       2004  [Produced by Kanye West and Brian Miller] [Int...            en
# 4       2005  [Intro] So they ask me "Young boy What you gon...            en
# ...      ...                                                ...           ...
# 779754  1979  [COMPANY] Lift your razor high, Sweeney! Hear ...            en
# 779755  2015  Don't give me that shit Cause I don't care wha...            en
# 779756  2001  Let me just ask you How you could do it How co...            en
# 779757  2006  As I try to fill all of my empty days I stumbl...            en
# 779758  2002  There's no out, downside up for good No light,...            en
#
#                                                clean_text
# 0       [killa, cam, killa, cam, cam, killa, cam, kill...
# 1       [yeah, hah, yeah, rocafella, we, invite, you, ...
# 2       [maybe, cause, im, eatin, and, these, bastard,...
# 3       [ugh, killa, baby, kanye, this, that, heron, f...
# 4       [so, they, ask, me, young, boy, what, you, gon...
# ...                                                   ...
# 779754  [lift, your, razor, high, sweeney, hear, it, s...
# 779755  [dont, give, me, that, shit, cause, i, dont, c...
# 779756  [let, me, just, ask, you, how, you, could, do,...
# 779757  [a, i, try, to, fill, all, of, my, empty, day,...
# 779758  [there, no, out, downside, up, for, good, no, ...
#
# [779759 rows x 6 columns]

# %%
import pandas as pd


words = pd.read_csv('raw_data/top_30_words.csv')

# %%
words
# Out:
#        Topic                                              Words
# 0    Topic 0  haha, girl, add, rock, guess, dont, dude, cd, ...
# 1    Topic 1  lol, ok, oh, like, thats, hot, exam, forward, ...
# 2    Topic 2  know, back, glad, tomorrow, welcome, school, r...
# 3    Topic 3  help, something, write, early, link, line, ema...
# 4    Topic 4  love, everyone, cute, summer, run, class, hope...
# 5    Topic 5  morning, good morning, good, sleep, go, goodni...
# 6    Topic 6  hope, tweet, wow, hour, yesterday, may, anyone...
# 7    Topic 7  twitter, two, phone, true, almost, every, supp...
# 8    Topic 8  play, home, ah, yet, face, hand, sunny, bet, c...
# 9    Topic 9  start, sure, bed, give, time, coffee, least, g...
# 10  Topic 10  happy, yay, im, mean, job, kinda, seriously, p...
# 11  Topic 11  hey, ya, meet, wonderful, pm, busy, worth, go ...
# 12  Topic 12  watch, well, luck, wish, train, congrats, tota...
# 13  Topic 13  need, tell, always, later, okay, around, lmao,...
# 14  Topic 14  awesome, excite, read, even, keep, want, ever,...
# 15  Topic 15  let, talk, actually, saw, smile, sit, bring, k...
# 16  Topic 16  great, god, head, yea, anyway, get home, choco...
# 17  Topic 17  thank, yes, way, take, long, bite, monday, fam...
# 18  Topic 18  much, soon, video, brother, someone, change, e...
# 19  Topic 19  would, really, first, though, send, dance, lov...
# 20  Topic 20  come, nice, people, day, wake, album, rain, ba...
# 21  Topic 21  lt, year, hello, old, pay, picture, get, walk,...
# 22  Topic 22  night, house, last, feel, so, stay, last night...
# 23  Topic 23  cool, best, please, birthday, life, baby, part...
# 24  Topic 24  better, little, week, man, name, put, photo, g...
# 25  Topic 25  new, tonight, hear, follower, also, update, mi...
# 26  Topic 26  make, listen, sorry, interest, ice, eye, bless...
# 27  Topic 27  wait, try, pic, weekend, plan, must, cant wait...
# 28  Topic 28  one, friend, say, use, call, music, game, ask,...
# 29  Topic 29  look, check, movie, stuff, still, hehe, like, ...
# 30  Topic 30  funny, boy, idea, stop, btw, friday, share, an...
# 31  Topic 31  good, drink, good night, forget, perfect, city...
# 32  Topic 32  hi, lot, another, already, leave, book, ha, bl...
# 33  Topic 33  yeah, show, finally, could, aw, omg, win, im, ...
# 34  Topic 34  next, beautiful, bore, remember, go, beach, aw...
# 35  Topic 35  guy, see, buy, vote, dinner, favorite, vip, ha...
# 36  Topic 36  follow, work, amaze, lunch, good luck, good, h...
# 37  Topic 37  fun, song, eat, sound, live, pretty, finish, s...
# 38  Topic 38  right, thing, enjoy, think, find, world, hahah...
# 39  Topic 39  maybe, post, never, get, tire, worry, drive, c...

# %% [markdown]
# # CREATE UNIQUE LIST

# %%
import pandas as pd

def generate_unique_words_from_csv(file_path):
    words_df = pd.read_csv(file_path)

    if 'Words' not in words_df.columns:
        raise ValueError("CSV file must contain a 'Words' column.")

    words_column = words_df['Words'].dropna().astype(str).tolist()
    split_words = [word.strip() for entry in words_column for word in entry.split(',')]
    unique_words = set(split_words)
    unique_words_sorted = sorted(unique_words)

    return unique_words_sorted

# Example usage
file_path = 'raw_data/top_30_words.csv'
unique_words_list = generate_unique_words_from_csv(file_path)
print(unique_words_list)
# Out:
# ['aa', 'able', 'absolutely', 'account', 'actually', 'ad', 'add', 'addict', 'advice', 'afternoon', 'age', 'ago', 'agree', 'ah', 'ahh', 'aint', 'airport', 'album', 'alex', 'alive', 'almost', 'alone', 'along', 'alot', 'already', 'alright', 'also', 'always', 'amaze', 'angel', 'annoy', 'another', 'answer', 'anyone', 'anything', 'anyway', 'apparently', 'apple', 'application', 'appreciate', 'around', 'arrive', 'art', 'ask', 'asleep', 'australia', 'avatar', 'aw', 'award', 'away', 'awesome', 'aww', 'babe', 'baby', 'back', 'back work', 'background', 'bad', 'bag', 'bake', 'band', 'bar', 'bath', 'bbq', 'bday', 'beach', 'bear', 'beat', 'beautiful', 'beautiful day', 'become', 'bed', 'beer', 'begin', 'behind', 'believe', 'best', 'best friend', 'bet', 'better', 'bf', 'big', 'bike', 'birthday', 'bitch', 'bite', 'black', 'blast', 'bless', 'blog', 'blood', 'blue', 'boo', 'book', 'bore', 'bos', 'bottle', 'bout', 'box', 'boy', 'boyfriend', 'brain', 'brand', 'break', 'breakfast', 'bright', 'brilliant', 'bring', 'bro', 'brother', 'btw', 'buddy', 'bug', 'build', 'burn', 'bus', 'business', 'busy', 'button', 'buy', 'bye', 'cake', 'call', 'camera', 'camp', 'cant', 'cant wait', 'car', 'card', 'care', 'case', 'cast', 'cat', 'catch', 'cause', 'cd', 'celebrate', 'chance', 'change', 'chat', 'check', 'cheer', 'cheese', 'chicken', 'chill', 'chillin', 'chocolate', 'choice', 'church', 'city', 'class', 'classic', 'clean', 'clear', 'click', 'client', 'close', 'closer', 'club', 'coast', 'coffee', 'cold', 'college', 'color', 'colour', 'come', 'come back', 'come home', 'comment', 'company', 'complain', 'complete', 'completely', 'computer', 'concert', 'congrats', 'congratulation', 'consider', 'cook', 'cooky', 'cool', 'could', 'count', 'country', 'couple', 'course', 'cousin', 'cover', 'crazy', 'cream', 'create', 'cross', 'cry', 'cup', 'currently', 'cut', 'cute', 'cuz', 'dad', 'daddy', 'damn', 'dance', 'dark', 'date', 'daughter', 'day', 'day get', 'day school', 'day today', 'day work', 'de', 'dear', 'decide', 'def', 'definitely', 'delicious', 'deserve', 'design', 'didnt', 'different', 'dinner', 'disney', 'dm', 'doctor', 'dog', 'doll', 'dont', 'download', 'draw', 'dream', 'dress', 'drink', 'drive', 'drop', 'dude', 'dunno', 'dvd', 'ear', 'earlier', 'early', 'easier', 'east', 'easy', 'eat', 'egg', 'eh', 'either', 'el', 'else', 'email', 'end', 'english', 'enjoy', 'enough', 'episode', 'especially', 'even', 'event', 'ever', 'every', 'everybody', 'everyday', 'everyone', 'everything', 'exactly', 'exam', 'excellent', 'excite', 'excuse', 'expect', 'experience', 'extra', 'eye', 'face', 'facebook', 'fact', 'fail', 'fair', 'fall', 'fam', 'family', 'fan', 'fantastic', 'far', 'fast', 'fav', 'favorite', 'favourite', 'fb', 'feature', 'fee', 'feel', 'feel better', 'feel good', 'feel like', 'fight', 'figure', 'fill', 'film', 'final', 'finally', 'finally get', 'find', 'fine', 'finger', 'finish', 'fire', 'first', 'first day', 'first time', 'fish', 'fit', 'fix', 'flight', 'fly', 'folk', 'follow', 'follower', 'food', 'foot', 'forever', 'forget', 'form', 'forward', 'free', 'fresh', 'friday', 'friend', 'front', 'fuck', 'full', 'fun', 'funny', 'future', 'game', 'garden', 'geek', 'german', 'get', 'get back', 'get better', 'get follower', 'get home', 'get love', 'get new', 'get ready', 'get twitter', 'gettin', 'gift', 'gig', 'girl', 'give', 'glad', 'glad like', 'go', 'go back', 'go bed', 'go get', 'go go', 'go make', 'go see', 'go sleep', 'go watch', 'go well', 'go work', 'god', 'goin', 'good', 'good day', 'good idea', 'good luck', 'good morning', 'good night', 'good thing', 'good time', 'goodness', 'goodnight', 'google', 'gorgeous', 'gosh', 'graduation', 'great', 'great day', 'great time', 'green', 'grow', 'guess', 'guitar', 'guy', 'gym', 'ha', 'hah', 'haha', 'hahah', 'hahaha', 'hahahaha', 'hair', 'half', 'hand', 'hang', 'hangover', 'hannah', 'happen', 'happy', 'happy bday', 'happy birthday', 'hard', 'hat', 'hate', 'head', 'hear', 'heart', 'hehe', 'hehehe', 'hell', 'hello', 'help', 'hey', 'hi', ' ...

# %% [markdown]
# ## QUERY TAGS

# %%
def extract_tags(clean_text, unique_words_list):
    unique_words_set = set(unique_words_list)  # Convert to set for faster lookup
    tags = [word for word in clean_text if word in unique_words_set]
    return tags if tags else None

# Define process_dataframe_in_batches function
def process_dataframe_in_batches(df, unique_words_list, batch_size=100):
    processed_chunks = []
    num_batches = (len(df) + batch_size - 1) // batch_size

    for i in range(num_batches):
        start_idx = i * batch_size
        end_idx = min((i + 1) * batch_size, len(df))
        batch = df.iloc[start_idx:end_idx].copy()
        
        # Apply the extract_tags function to the 'clean_text' column
        batch['tags'] = batch['clean_text'].apply(lambda x: extract_tags(x, unique_words_list))
        
        processed_chunks.append(batch)
        print(f"✅ Batch {i + 1}/{num_batches} processed ({batch.shape[0]} rows)")
    
    # Concatenate all processed chunks into a single DataFrame
    full_data = pd.concat(processed_chunks, ignore_index=True)
    return full_data

# %%
first_million_clean_tags = process_dataframe_in_batches(first_million_clean, unique_words_list, batch_size=10_000)
# Out:
# ✅ Batch 1/78 processed (10000 rows)
# ✅ Batch 2/78 processed (10000 rows)
# ✅ Batch 3/78 processed (10000 rows)
# ✅ Batch 4/78 processed (10000 rows)
# ✅ Batch 5/78 processed (10000 rows)
# ✅ Batch 6/78 processed (10000 rows)
# ✅ Batch 7/78 processed (10000 rows)
# ✅ Batch 8/78 processed (10000 rows)
# ✅ Batch 9/78 processed (10000 rows)
# ✅ Batch 10/78 processed (10000 rows)
# ✅ Batch 11/78 processed (10000 rows)
# ✅ Batch 12/78 processed (10000 rows)
# ✅ Batch 13/78 processed (10000 rows)
# ✅ Batch 14/78 processed (10000 rows)
# ✅ Batch 15/78 processed (10000 rows)
# ✅ Batch 16/78 processed (10000 rows)
# ✅ Batch 17/78 processed (10000 rows)
# ✅ Batch 18/78 processed (10000 rows)
# ✅ Batch 19/78 processed (10000 rows)
# ✅ Batch 20/78 processed (10000 rows)
# ✅ Batch 21/78 processed (10000 rows)
# ✅ Batch 22/78 processed (10000 rows)
# ✅ Batch 23/78 processed (10000 rows)
# ✅ Batch 24/78 processed (10000 rows)
# ✅ Batch 25/78 processed (10000 rows)
# ✅ Batch 26/78 processed (10000 rows)
# ✅ Batch 27/78 processed (10000 rows)
# ✅ Batch 28/78 processed (10000 rows)
# ✅ Batch 29/78 processed (10000 rows)
# ✅ Batch 30/78 processed (10000 rows)
# ✅ Batch 31/78 processed (10000 rows)
# ✅ Batch 32/78 processed (10000 rows)
# ✅ Batch 33/78 processed (10000 rows)
# ✅ Batch 34/78 processed (10000 rows)
# ✅ Batch 35/78 processed (10000 rows)
# ✅ Batch 36/78 processed (10000 rows)
# ✅ Batch 37/78 processed (10000 rows)
# ✅ Batch 38/78 processed (10000 rows)
# ✅ Batch 39/78 processed (10000 rows)
# ✅ Batch 40/78 processed (10000 rows)
# ✅ Batch 41/78 processed (10000 rows)
# ✅ Batch 42/78 processed (10000 rows)
# ✅ Batch 43/78 processed (10000 rows)
# ✅ Batch 44/78 processed (10000 rows)
# ✅ Batch 45/78 processed (10000 rows)
# ✅ Batch 46/78 processed (10000 rows)
# ✅ Batch 47/78 processed (10000 rows)
# ✅ Batch 48/78 processed (10000 rows)
# ✅ Batch 49/78 processed (10000 rows)
# ✅ Batch 50/78 processed (10000 rows)
# ✅ Batch 51/78 processed (10000 rows)
# ✅ Batch 52/78 processed (10000 rows)
# ✅ Batch 53/78 processed (10000 rows)
# ✅ Batch 54/78 processed (10000 rows)
# ✅ Batch 55/78 processed (10000 rows)
# ✅ Batch 56/78 processed (10000 rows)
# ✅ Batch 57/78 processed (10000 rows)
# ✅ Batch 58/78 processed (10000 rows)
# ✅ Batch 59/78 processed (10000 rows)
# ✅ Batch 60/78 processed (10000 rows)
# ✅ Batch 61/78 processed (10000 rows)
# ✅ Batch 62/78 processed (10000 rows)
# ✅ Batch 63/78 processed (10000 rows)
# ✅ Batch 64/78 processed (10000 rows)
# ✅ Batch 65/78 processed (10000 rows)
# ✅ Batch 66/78 processed (10000 rows)
# ✅ Batch 67/78 processed (10000 rows)
# ✅ Batch 68/78 processed (10000 rows)
# ✅ Batch 69/78 processed (10000 rows)
# ✅ Batch 70/78 processed (10000 rows)
# ✅ Batch 71/78 processed (10000 rows)
# ✅ Batch 72/78 processed (10000 rows)
# ✅ Batch 73/78 processed (10000 rows)
# ✅ Batch 74/78 processed (10000 rows)
# ✅ Batch 75/78 processed (10000 rows)
# ✅ Batch 76/78 processed (10000 rows)
# ✅ Batch 77/78 processed (10000 rows)
# ✅ Batch 78/78 processed (9759 rows)

# %%
first_million_clean_tags['clean_text'][0], first_million_clean_tags['tags'][0]
# Out:
# (array(['killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa',
#         'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa', 'cam',
#         'cam', 'killa', 'killa', 'killa', 'cam', 'killa', 'cam', 'cam',
#         'killa', 'killa', 'killa', 'cam', 'killa', 'cam', 'cam', 'base',
#         'load', 'killa', 'cam', 'killa', 'cam', 'uhhuh', 'killa', 'cam',
#         'cam', 'santana', 'on', 'second', 'jim', 'on', 'third', 'killa',
#         'cam', 'killa', 'cam', 'cam', 'im', 'at', 'bat', 'killa', 'killa',
#         'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'im', 'bout', 'to',
#         'hit', 'this', 'shit', 'out', 'the', 'world', 'killa', 'cam',
#         'ugh', 'heatmakerz', 'killa', 'cam', 'cam', 'killa', 'cam',
#         'killa', 'cam', 'killa', 'cam', 'cam', 'hahahaha', 'killa', 'cam',
#         'killa', 'cam', 'cam', 'killa', 'killa', 'killa', 'cam', 'killa',
#         'cam', 'cam', 'killa', 'we', 'make', 'this', 'shit', 'clap',
#         'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa',
#         'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa', 'cam',
#         'cam', 'killa', 'killa', 'killa', 'cam', 'killa', 'killa', 'killa',
#         'cam', 'cam', 'killa', 'with', 'the', 'goon', 'i', 'spar', 'stay',
#         'in', 'tune', 'with', 'ma', 'what', 'up', 'she', 'like', 'damn',
#         'this', 'the', 'realest', 'since', 'kumbaya', 'bomaye', 'killa',
#         'cam', 'my', 'lord', 'my', 'lord', 'still', 'the', 'man', 'with',
#         'the', 'pan', 'scrilla', 'fam', 'on', 'board', 'now', 'bitch',
#         'they', 'want', 'to', 'neuter', 'me', 'nigga', 'they', 'want',
#         'to', 'tutor', 'me', 'the', 'hooligan', 'in', 'houlihans',
#         'maneuver', 'nothing', 'new', 'to', 'me', 'doggy', 'im', 'from',
#         'the', 'land', 'of', 'grind', 'panpan', 'gram', 'or', 'dime',
#         'not', 'toe', 'or', 'mc', 'when', 'i', 'say', 'hammer', 'time',
#         'beef', 'i', 'hammer', 'mine', 'when', 'i', 'get', 'my', 'hand',
#         'on', 'nine', 'if', 'i', 'have', 'on', 'bama', 'line', 'corduroy',
#         'camll', 'shine', 'canary', 'burgundy', 'i', 'call', 'it', 'lemon',
#         'red', 'red', 'yellow', 'diamond', 'in', 'my', 'ear', 'call', 'em',
#         'lemonheads', 'lemonhead', 'end', 'up', 'dead', 'ice', 'like',
#         'winnipeg', 'gemstone', 'flintstone', 'you', 'could', 'say', 'im',
#         'friend', 'with', 'fred', 'you', 'unhappy', 'scrappy', 'whats',
#         'go', 'on', 'scrappy', 'i', 'get', 'pataki', 'at', 'me', 'bitch',
#         'say', 'im', 'tacky', 'daddy', 'range', 'look', 'like', 'laffy',
#         'taffy', 'killa', 'cam', 'killa', 'cam', 'cam', 'sing', 'killa',
#         'cam', 'killa', 'cam', 'killa', 'cam', 'cam', 'uhh', 'it', 'me',
#         'clap', 'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'killa',
#         'killa', 'cam', 'sing', 'killa', 'cam', 'cam', 'killa', 'uhh',
#         'it', 'me', 'clap', 'killa', 'cam', 'killa', 'cam', 'cam', 'sing',
#         'killa', 'cam', 'killa', 'cam', 'killa', 'cam', 'cam', 'clap',
#         'it', 'me', 'killa', 'cam', 'killa', 'cam', 'cam', 'killa',
#         'killa', 'killa', 'cam', 'clap', 'harlem', 'i', 'know', 'yall',
#         'know', 'about', 'this', 'killa', 'cam', 'cam', 'killa', 'killa',
#         'yo', 'im', 'from', 'where', 'nicky', 'barnes', 'get', 'rich', 'a',
#         'fuck', 'rich', 'and', 'a', 'hit', 'the', 'kitchen', 'then', 'be',
#         'pitchin', 'up', 'rob', 'base', 'mase', 'doug', 'e', 'fresh',
#         'switch', 'it', 'up', 'i', 'do', 'both', 'who', 'be', 'i', 'to',
#         'fuck', 'tradition', 'up', 'killa', 'so', 'i', 'park', 'in', 'a',
#         'towaway', 'zone', 'chromei', 'dont', 'care', 'that', 'car', 'a',
#         'throwaway', 'home', 'killa', 'welcome', 'to', 'harlem', 'where',
#         'you', 'welcome', 'to', 'problem', 'off', 'of', 'furlough',
#         'fellow', 'felon', 'get', 'pardon', 'them', 'nigga', 'know', 'we',
#         'bang', 'stand', 'out', 'like', 'pootie', 'tang', 'soon', 'a',
#         'the', 'stoolie', 'sing', 'that', 'when', 'the', 'toolie', 'sing',
#         'bang', 'bang', 'come', 'from', 'that', 'movie', 'ring', 'snap',
#         'crack', 'jewelry', 'bling', 'flapjack', 'ooh', 'he', 'bring',
#         'clackclack', 'ooh', 'he', 'ring', 'bad', 'rap', 'cuties', 'cling',
#         'as', 'cap', 'put', 'them', 'in', 'the', 'river', 'im', 'the',
#         'sushi', 'king', 'and', 'ima', 'keep', 'ya', 'fresh', 'let', 'the'],
#        dtype=object),
#  ['load',
#   'second',
#   'im',
#   'im',
#   'bout',
#   'hit',
#   'shit',
#   'world',
#   'ugh',
#   'hahahaha',
#   'make',
#   'shit',
#   'stay',
#   'tune',
#   'what',
#   'like',
#   'damn',
#   'since',
#   'still',
#   'man',
#   'fam',
#   'bitch',
#   'want',
#   'want',
#   'nothing',
#   'new',
#   'im',
#   'land',
#   'say',
#   'time',
#   'mine',
#   'get',
#   'hand',
#   'line',
#   'call',
#   'red',
#   'red',
#   'ear',
#   'call',
#   'end',
#   'ice',
#   'like',
#   'you',
#   'could',
#   'say',
#   'im',
#   'friend',
#   'you',
#   'whats',
#   'go',
#   'get',
#   'bitch',
#   'say',
#   'im',
#   'daddy',
#   'look',
#   'like',
#   'sing',
#   'sing',
#   'sing',
#   'know',
#   'yall',
#   'know',
#   'yo',
#   'im',
#   'get',
#   'fuck',
#   'hit',
#   'kitchen',
#   'fresh',
#   'fuck',
#   'so',
#   'park',
#   'dont',
#   'care',
#   'car',
#   'home',
#   'welcome',
#   'you',
#   'welcome',
#   'problem',
#   'get',
#   'know',
#   'stand',
#   'like',
#   'soon',
#   'sing',
#   'sing',
#   'come',
#   'movie',
#   'ring',
#   'ooh',
#   'bring',
#   'ooh',
#   'ring',
#   'bad',
#   'put',
#   'im',
#   'king',
#   'keep',
#   'ya',
#   'fresh',
#   'let'])

# %%
first_million_clean_tags.dtypes
# Out:
# title            object
# artist           object
# year              int64
# lyrics           object
# language_cld3    object
# clean_text       object
# tags             object
# dtype: object

# %% [markdown]
# # AMEND DATAFRAME

# %%
first_million_clean_tags['tags']
# Out:
# 0         [load, second, im, im, bout, hit, shit, world,...
# 1         [yeah, hah, yeah, you, you, know, well, sort, ...
# 2         [maybe, cause, im, like, you, see, cant, so, i...
# 3         [ugh, baby, huh, yeah, let, ugh, im, back, ugh...
# 4         [so, ask, young, boy, what, you, second, time,...
#                                 ...
# 779754    [high, hear, sing, yes, laugh, often, smile, s...
# 779755    [dont, give, shit, cause, dont, care, what, yo...
# 779756    [let, ask, you, you, could, could, you, turn, ...
# 779757    [try, fill, day, round, past, stay, go, ride, ...
# 779758    [no, good, no, light, understand, try, hurt, f...
# Name: tags, Length: 779759, dtype: object

# %%
first_million_clean_tags['tag_len'] = first_million_clean_tags['tags'].str.len()

# %%
first_million_clean_tags
# Out:
#                                                     title              artist  \
# 0                                               Killa Cam             Cam'ron
# 1                                              Can I Live               JAY-Z
# 2                                       Forgive Me Father            Fabolous
# 3                                            Down and Out             Cam'ron
# 4                                                  Fly In           Lil Wayne
# ...                                                   ...                 ...
# 779754  The Ballad of Sweeney Todd: “Lift Your Razor H...    Stephen Sondheim
# 779755                                      Progress live         Knife Fight
# 779756                                   Dont Come For Me            Ari Gold
# 779757                        Benton Harbor Blues reprise  The Fiery Furnaces
# 779758                                           Solitude      Jerry Cantrell
#
#         year                                             lyrics language_cld3  \
# 0       2004  [Chorus: Opera Steve & Cam'ron] Killa Cam, Kil...            en
# 1       1996  [Produced by Irv Gotti] [Intro] Yeah, hah, yea...            en
# 2       2003  Maybe cause I'm eatin And these bastards fiend...            en
# 3       2004  [Produced by Kanye West and Brian Miller] [Int...            en
# 4       2005  [Intro] So they ask me "Young boy What you gon...            en
# ...      ...                                                ...           ...
# 779754  1979  [COMPANY] Lift your razor high, Sweeney! Hear ...            en
# 779755  2015  Don't give me that shit Cause I don't care wha...            en
# 779756  2001  Let me just ask you How you could do it How co...            en
# 779757  2006  As I try to fill all of my empty days I stumbl...            en
# 779758  2002  There's no out, downside up for good No light,...            en
#
#                                                clean_text  \
# 0       [killa, cam, killa, cam, cam, killa, cam, kill...
# 1       [yeah, hah, yeah, rocafella, we, invite, you, ...
# 2       [maybe, cause, im, eatin, and, these, bastard,...
# 3       [ugh, killa, baby, kanye, this, that, heron, f...
# 4       [so, they, ask, me, young, boy, what, you, gon...
# ...                                                   ...
# 779754  [lift, your, razor, high, sweeney, hear, it, s...
# 779755  [dont, give, me, that, shit, cause, i, dont, c...
# 779756  [let, me, just, ask, you, how, you, could, do,...
# 779757  [a, i, try, to, fill, all, of, my, empty, day,...
# 779758  [there, no, out, downside, up, for, good, no, ...
#
#                                                      tags  tag_len
# 0       [load, second, im, im, bout, hit, shit, world,...    103.0
# 1       [yeah, hah, yeah, you, you, know, well, sort, ...    145.0
# 2       [maybe, cause, im, like, you, see, cant, so, i...    137.0
# 3       [ugh, baby, huh, yeah, let, ugh, im, back, ugh...    165.0
# 4       [so, ask, young, boy, what, you, second, time,...    157.0
# ...                                                   ...      ...
# 779754  [high, hear, sing, yes, laugh, often, smile, s...     13.0
# 779755  [dont, give, shit, cause, dont, care, what, yo...     36.0
# 779756  [let, ask, you, you, could, could, you, turn, ...     94.0
# 779757  [try, fill, day, round, past, stay, go, ride, ...     31.0
# 779758  [no, good, no, light, understand, try, hurt, f...     39.0
#
# [779759 rows x 8 columns]

# %%
first_million_clean_tags.drop(columns=['year', 'lyrics', 'language_cld3', 'tag_len'], inplace=True)

# %%
first_million_clean_tags
# Out:
#                                                     title              artist  \
# 0                                               Killa Cam             Cam'ron
# 1                                              Can I Live               JAY-Z
# 2                                       Forgive Me Father            Fabolous
# 3                                            Down and Out             Cam'ron
# 4                                                  Fly In           Lil Wayne
# ...                                                   ...                 ...
# 779754  The Ballad of Sweeney Todd: “Lift Your Razor H...    Stephen Sondheim
# 779755                                      Progress live         Knife Fight
# 779756                                   Dont Come For Me            Ari Gold
# 779757                        Benton Harbor Blues reprise  The Fiery Furnaces
# 779758                                           Solitude      Jerry Cantrell
#
#                                                clean_text  \
# 0       [killa, cam, killa, cam, cam, killa, cam, kill...
# 1       [yeah, hah, yeah, rocafella, we, invite, you, ...
# 2       [maybe, cause, im, eatin, and, these, bastard,...
# 3       [ugh, killa, baby, kanye, this, that, heron, f...
# 4       [so, they, ask, me, young, boy, what, you, gon...
# ...                                                   ...
# 779754  [lift, your, razor, high, sweeney, hear, it, s...
# 779755  [dont, give, me, that, shit, cause, i, dont, c...
# 779756  [let, me, just, ask, you, how, you, could, do,...
# 779757  [a, i, try, to, fill, all, of, my, empty, day,...
# 779758  [there, no, out, downside, up, for, good, no, ...
#
#                                                      tags
# 0       [load, second, im, im, bout, hit, shit, world,...
# 1       [yeah, hah, yeah, you, you, know, well, sort, ...
# 2       [maybe, cause, im, like, you, see, cant, so, i...
# 3       [ugh, baby, huh, yeah, let, ugh, im, back, ugh...
# 4       [so, ask, young, boy, what, you, second, time,...
# ...                                                   ...
# 779754  [high, hear, sing, yes, laugh, often, smile, s...
# 779755  [dont, give, shit, cause, dont, care, what, yo...
# 779756  [let, ask, you, you, could, could, you, turn, ...
# 779757  [try, fill, day, round, past, stay, go, ride, ...
# 779758  [no, good, no, light, understand, try, hurt, f...
#
# [779759 rows x 4 columns]

# %% [markdown]
# # FINAL EXPORT TO FEATHER

# %%
import pyarrow.feather as feather

feather.write_feather(first_million_clean_tags, 'first_million_clean_tags.feather')

# %%
import pyarrow.feather as feather

first_million_clean_tags = feather.read_feather('first_million_clean_tags.feather')

# %%
import pyarrow.feather as feather

first_million_clean_tags = feather.read_feather('raw_data/first_million_clean_tags.feather')

# %%
type(first_million_clean_tags)
# Out:
# pandas.core.frame.DataFrame

# %%
first_million_clean_tags.isnull().sum()
# Out:
# title         13
# artist         0
# clean_text     0
# tags          79
# dtype: int64

# %%
first_million_clean_tags = first_million_clean_tags.dropna(axis=0)

# %%
first_million_clean_tags.shape
# Out:
# (779667, 4)

# %%
feather.write_feather(first_million_clean_tags, 'first_million_clean_tags_02.feather')

# %%
first_million_clean_tags_02 = feather.read_feather('first_million_clean_tags_02.feather')

# %%
first_million_clean_tags_02.isnull().sum()
# Out:
# title         0
# artist        0
# clean_text    0
# tags          0
# dtype: int64

# %%
first_million_clean_tags['tags'][0]
# Out:
# array(['load', 'second', 'im', 'im', 'bout', 'hit', 'shit', 'world',
#        'ugh', 'hahahaha', 'make', 'shit', 'stay', 'tune', 'what', 'like',
#        'damn', 'since', 'still', 'man', 'fam', 'bitch', 'want', 'want',
#        'nothing', 'new', 'im', 'land', 'say', 'time', 'mine', 'get',
#        'hand', 'line', 'call', 'red', 'red', 'ear', 'call', 'end', 'ice',
#        'like', 'you', 'could', 'say', 'im', 'friend', 'you', 'whats',
#        'go', 'get', 'bitch', 'say', 'im', 'daddy', 'look', 'like', 'sing',
#        'sing', 'sing', 'know', 'yall', 'know', 'yo', 'im', 'get', 'fuck',
#        'hit', 'kitchen', 'fresh', 'fuck', 'so', 'park', 'dont', 'care',
#        'car', 'home', 'welcome', 'you', 'welcome', 'problem', 'get',
#        'know', 'stand', 'like', 'soon', 'sing', 'sing', 'come', 'movie',
#        'ring', 'ooh', 'bring', 'ooh', 'ring', 'bad', 'put', 'im', 'king',
#        'keep', 'ya', 'fresh', 'let'], dtype=object)

# %% [markdown]
# ## CHECK UNIQUE VALUES IN THE LENGHT OF THE TAGS

# %%
import matplotlib.pyplot as plt

first_million_clean_tags['tag_len'].unique()
# Out:
# array([103., 145., 137., 165., 157., 167., 177., 138., 163., 220., 162.,
#        182., 143., 194., 161., 197., 180., 140., 191., 130., 172., 166.,
#        206., 118., 181., 117., 173., 115., 201., 188., 158., 149., 155.,
#        202., 227., 144., 175., 156., 133., 207., 152., 146., 123., 153.,
#        245., 178., 215., 159., 176., 209., 168., 195., 212., 184., 214.,
#        186., 170., 150., 169., 204., 126., 192., 151., 124., 147., 171.,
#        190., 233., 183., 200., 164., 236.,  47., 208., 160., 223., 154.,
#        211., 199., 187., 174., 198.,  14., 114., 196.,  77., 125., 232.,
#         80., 142., 122., 213., 139., 205., 148., 219., 210., 179., 119.,
#        203., 185., 218., 221., 120., 132.,  81., 111., 116., 121.,  89.,
#         96.,  53., 129., 127., 226., 113.,  57., 234., 255., 136., 193.,
#        189., 134., 131., 229., 217., 141., 224., 225., 108., 241., 237.,
#        235.,  32., 135.,  31.,  37.,  34.,  85.,  51., 249.,  61.,  92.,
#         99.,  97., 128.,  63.,  42., 310.,  93.,  52.,  30., 253., 238.,
#        288.,  75., 110.,   6.,  98., 107.,  12., 242.,  58.,  56.,  67.,
#        281., 104.,  29., 216.,  27., 102., 250., 228.,  19.,  95.,  70.,
#        112.,  68.,  62.,  40.,  86.,  60.,  87.,   9.,  55., 243.,  76.,
#         43.,  49., 258.,  65., 240.,   7.,  10.,  45.,  79.,  90.,  50.,
#         36., 230., 106.,  28.,  73., 297., 222.,  23.,  84.,  38., 109.,
#         64., 316.,  71.,  83.,  59., 247., 231., 268., 323.,  78.,  66.,
#        239., 263., 264.,  46.,  48.,  94.,  39.,  26.,  13.,  33.,  69.,
#        266., 278., 272.,  88., 100.,  44., 254.,  91.,  72.,  41., 259.,
#         35.,  74.,  82., 101., 244., 105.,  22., 273.,  15.,  18., 251.,
#        267., 257., 284., 270., 246.,  54., 256., 248., 269., 277.,  21.,
#        283.,  16.,  17., 252.,  25.,  20., 291., 262., 275., 260.,   8.,
#        261., 298.,  24., 329., 279., 271.,   3., 265., 301.,  11., 280.,
#        285., 289., 336., 295., 312., 274., 293.,   5.,   2., 282., 290.,
#        338., 276., 286., 299., 287., 294.,   4., 296., 309., 292.,  nan,
#        322., 300., 302., 303., 313., 306., 308., 346.,   1., 304., 319.,
#        321., 341., 320., 305., 307., 328., 331., 311., 314., 326., 327.,
#        317., 334., 347., 387., 353., 330., 325., 337., 359., 315., 356.,
#        366., 365., 342., 343., 348., 372., 324., 357., 364., 379., 390.,
#        363.])

# %%
def check_tags_in_text_and_list(dataframe, unique_list):
    # Specific variables
    tags = dataframe['tags'][0]
    clean_text = dataframe['clean_text'][0]
    
    # Check if all tags are in clean_text
    all_tags_in_clean_text = all(tag in clean_text for tag in tags)
    
    # Check if all tags are in unique_words_list
    all_tags_in_unique_words_list = all(tag in unique_list for tag in tags)
    
    return all_tags_in_clean_text, all_tags_in_unique_words_list

# Check if all tags are in clean_text and unique_words_list for the first row
all_tags_in_clean_text, all_tags_in_unique_words_list = check_tags_in_text_and_list(first_million_clean_tags, unique_words_list)

# Print results
print(f"All tags in clean_text: {all_tags_in_clean_text}")
print(f"All tags in unique_words_list: {all_tags_in_unique_words_list}")
# Out:
# All tags in clean_text: True
# All tags in unique_words_list: True

# %% [markdown]
# ### DEBUG

# %%
def extract_tags(clean_text):
    # Ensure clean_text is a list of strings
    if not isinstance(clean_text, list):
        raise ValueError("clean_text must be a list of words")
    
    # Debug: Print out the clean_text to see the input
    print(f"Clean text input: {clean_text}")

    # Filter words that are in unique_words_list and remove duplicates
    tags = list(set(word for word in clean_text if word in unique_words_list))
    
    # Debug: Print out the tags to see the output
    print(f"Extracted tags: {tags}")

    return tags if tags else None

# %%
example_clean_text = ['so', 'they', 'ask', 'me', 'young', 'b']

# Run the function with example input
tags = extract_tags(example_clean_text)
print(f"Tags: {tags}")
# Out:
# Clean text input: ['so', 'they', 'ask', 'me', 'young', 'b']
# Extracted tags: ['so', 'young', 'ask']
# Tags: ['so', 'young', 'ask']

# %%
import pandas as pd
import numpy as np

def check_tags_in_text_and_list_per_row(dataframe, unique_list):
    # Lists to store results
    all_tags_in_clean_text_list = []
    all_tags_in_unique_words_list = []

    # Iterate over each row in the DataFrame
    for index, row in dataframe.iterrows():
        tags = row['tags']
        clean_text = row['clean_text']
        
        # Check if all tags are in clean_text
        all_tags_in_clean_text = all(tag in clean_text for tag in tags)
        
        # Check if all tags are in unique_words_list
        all_tags_in_unique_words = all(tag in unique_list for tag in tags)
        
        # Append results to lists
        all_tags_in_clean_text_list.append(all_tags_in_clean_text)
        all_tags_in_unique_words_list.append(all_tags_in_unique_words)
    
    return all_tags_in_clean_text_list, all_tags_in_unique_words_list

# Example unique words list

# Check if all tags are in clean_text and unique_words_list for each row
all_tags_in_clean_text_list, all_tags_in_unique_words_list = check_tags_in_text_and_list_per_row(first_million_clean_tags, unique_words_list)

# Print results for each row
for idx, (in_clean_text, in_unique_list) in enumerate(zip(all_tags_in_clean_text_list, all_tags_in_unique_words_list)):
    print(f"Row {idx}: All tags in clean_text: {in_clean_text}, All tags in unique_words_list: {in_unique_list}")
# Out:
# Row 0: All tags in clean_text: True, All tags in unique_words_list: True
# Row 1: All tags in clean_text: True, All tags in unique_words_list: True
# Row 2: All tags in clean_text: True, All tags in unique_words_list: True
# Row 3: All tags in clean_text: True, All tags in unique_words_list: True
# Row 4: All tags in clean_text: True, All tags in unique_words_list: True
# Row 5: All tags in clean_text: True, All tags in unique_words_list: True
# Row 6: All tags in clean_text: True, All tags in unique_words_list: True
# Row 7: All tags in clean_text: True, All tags in unique_words_list: True
# Row 8: All tags in clean_text: True, All tags in unique_words_list: True
# Row 9: All tags in clean_text: True, All tags in unique_words_list: True

# %%
first_million_clean_tags['clean_text'][0]
# Out:
# array(['killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa',
#        'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa', 'cam',
#        'cam', 'killa', 'killa', 'killa', 'cam', 'killa', 'cam', 'cam',
#        'killa', 'killa', 'killa', 'cam', 'killa', 'cam', 'cam', 'base',
#        'load', 'killa', 'cam', 'killa', 'cam', 'uhhuh', 'killa', 'cam',
#        'cam', 'santana', 'on', 'second', 'jim', 'on', 'third', 'killa',
#        'cam', 'killa', 'cam', 'cam', 'im', 'at', 'bat', 'killa', 'killa',
#        'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'im', 'bout', 'to',
#        'hit', 'this', 'shit', 'out', 'the', 'world', 'killa', 'cam',
#        'ugh', 'heatmakerz', 'killa', 'cam', 'cam', 'killa', 'cam',
#        'killa', 'cam', 'killa', 'cam', 'cam', 'hahahaha', 'killa', 'cam',
#        'killa', 'cam', 'cam', 'killa', 'killa', 'killa', 'cam', 'killa',
#        'cam', 'cam', 'killa', 'we', 'make', 'this', 'shit', 'clap',
#        'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa',
#        'cam', 'killa', 'cam', 'cam', 'killa', 'cam', 'killa', 'cam',
#        'cam', 'killa', 'killa', 'killa', 'cam', 'killa', 'killa', 'killa',
#        'cam', 'cam', 'killa', 'with', 'the', 'goon', 'i', 'spar', 'stay',
#        'in', 'tune', 'with', 'ma', 'what', 'up', 'she', 'like', 'damn',
#        'this', 'the', 'realest', 'since', 'kumbaya', 'bomaye', 'killa',
#        'cam', 'my', 'lord', 'my', 'lord', 'still', 'the', 'man', 'with',
#        'the', 'pan', 'scrilla', 'fam', 'on', 'board', 'now', 'bitch',
#        'they', 'want', 'to', 'neuter', 'me', 'nigga', 'they', 'want',
#        'to', 'tutor', 'me', 'the', 'hooligan', 'in', 'houlihans',
#        'maneuver', 'nothing', 'new', 'to', 'me', 'doggy', 'im', 'from',
#        'the', 'land', 'of', 'grind', 'panpan', 'gram', 'or', 'dime',
#        'not', 'toe', 'or', 'mc', 'when', 'i', 'say', 'hammer', 'time',
#        'beef', 'i', 'hammer', 'mine', 'when', 'i', 'get', 'my', 'hand',
#        'on', 'nine', 'if', 'i', 'have', 'on', 'bama', 'line', 'corduroy',
#        'camll', 'shine', 'canary', 'burgundy', 'i', 'call', 'it', 'lemon',
#        'red', 'red', 'yellow', 'diamond', 'in', 'my', 'ear', 'call', 'em',
#        'lemonheads', 'lemonhead', 'end', 'up', 'dead', 'ice', 'like',
#        'winnipeg', 'gemstone', 'flintstone', 'you', 'could', 'say', 'im',
#        'friend', 'with', 'fred', 'you', 'unhappy', 'scrappy', 'whats',
#        'go', 'on', 'scrappy', 'i', 'get', 'pataki', 'at', 'me', 'bitch',
#        'say', 'im', 'tacky', 'daddy', 'range', 'look', 'like', 'laffy',
#        'taffy', 'killa', 'cam', 'killa', 'cam', 'cam', 'sing', 'killa',
#        'cam', 'killa', 'cam', 'killa', 'cam', 'cam', 'uhh', 'it', 'me',
#        'clap', 'killa', 'cam', 'killa', 'cam', 'cam', 'killa', 'killa',
#        'killa', 'cam', 'sing', 'killa', 'cam', 'cam', 'killa', 'uhh',
#        'it', 'me', 'clap', 'killa', 'cam', 'killa', 'cam', 'cam', 'sing',
#        'killa', 'cam', 'killa', 'cam', 'killa', 'cam', 'cam', 'clap',
#        'it', 'me', 'killa', 'cam', 'killa', 'cam', 'cam', 'killa',
#        'killa', 'killa', 'cam', 'clap', 'harlem', 'i', 'know', 'yall',
#        'know', 'about', 'this', 'killa', 'cam', 'cam', 'killa', 'killa',
#        'yo', 'im', 'from', 'where', 'nicky', 'barnes', 'get', 'rich', 'a',
#        'fuck', 'rich', 'and', 'a', 'hit', 'the', 'kitchen', 'then', 'be',
#        'pitchin', 'up', 'rob', 'base', 'mase', 'doug', 'e', 'fresh',
#        'switch', 'it', 'up', 'i', 'do', 'both', 'who', 'be', 'i', 'to',
#        'fuck', 'tradition', 'up', 'killa', 'so', 'i', 'park', 'in', 'a',
#        'towaway', 'zone', 'chromei', 'dont', 'care', 'that', 'car', 'a',
#        'throwaway', 'home', 'killa', 'welcome', 'to', 'harlem', 'where',
#        'you', 'welcome', 'to', 'problem', 'off', 'of', 'furlough',
#        'fellow', 'felon', 'get', 'pardon', 'them', 'nigga', 'know', 'we',
#        'bang', 'stand', 'out', 'like', 'pootie', 'tang', 'soon', 'a',
#        'the', 'stoolie', 'sing', 'that', 'when', 'the', 'toolie', 'sing',
#        'bang', 'bang', 'come', 'from', 'that', 'movie', 'ring', 'snap',
#        'crack', 'jewelry', 'bling', 'flapjack', 'ooh', 'he', 'bring',
#        'clackclack', 'ooh', 'he', 'ring', 'bad', 'rap', 'cuties', 'cling',
#        'as', 'cap', 'put', 'them', 'in', 'the', 'river', 'im', 'the',
#        'sushi', 'king', 'and', 'ima', 'keep', 'ya', 'fresh', 'let', 'the'],
#       dtype=object)

# %%
first_million_clean_tags['tags'][0]
# Out:
# ['load',
#  'second',
#  'im',
#  'im',
#  'bout',
#  'hit',
#  'shit',
#  'world',
#  'ugh',
#  'hahahaha',
#  'make',
#  'shit',
#  'stay',
#  'tune',
#  'what',
#  'like',
#  'damn',
#  'since',
#  'still',
#  'man',
#  'fam',
#  'bitch',
#  'want',
#  'want',
#  'nothing',
#  'new',
#  'im',
#  'land',
#  'say',
#  'time',
#  'mine',
#  'get',
#  'hand',
#  'line',
#  'call',
#  'red',
#  'red',
#  'ear',
#  'call',
#  'end',
#  'ice',
#  'like',
#  'you',
#  'could',
#  'say',
#  'im',
#  'friend',
#  'you',
#  'whats',
#  'go',
#  'get',
#  'bitch',
#  'say',
#  'im',
#  'daddy',
#  'look',
#  'like',
#  'sing',
#  'sing',
#  'sing',
#  'know',
#  'yall',
#  'know',
#  'yo',
#  'im',
#  'get',
#  'fuck',
#  'hit',
#  'kitchen',
#  'fresh',
#  'fuck',
#  'so',
#  'park',
#  'dont',
#  'care',
#  'car',
#  'home',
#  'welcome',
#  'you',
#  'welcome',
#  'problem',
#  'get',
#  'know',
#  'stand',
#  'like',
#  'soon',
#  'sing',
#  'sing',
#  'come',
#  'movie',
#  'ring',
#  'ooh',
#  'bring',
#  'ooh',
#  'ring',
#  'bad',
#  'put',
#  'im',
#  'king',
#  'keep',
#  'ya',
#  'fresh',
#  'let']

# %% [markdown]
# ### DEBUG

# %%
def check_words_in_unique_list(words_list, unique_list):
    # Check if all words in words_list are in unique_list
    all_words_in_unique_list = all(word in unique_list for word in words_list)
    
    return all_words_in_unique_list

# Check if all test_lda words are in unique_words_list
all_words_in_unique_list = check_words_in_unique_list(test_lda, unique_words_list)

# Print result
print(f"All words in unique_words_list: {all_words_in_unique_list}")
# Out:
# All words in unique_words_list: True

# %% [markdown]
# # WORK ON LOGIC TO GET SONGS

# %% [markdown]
# ## LDA TEST RESULT

# %%
top_words = ['last', 'feel', 'last night', 'issue', 'ear']

# %%
unique_words_list
# Out:
# ['aa',
#  'able',
#  'absolutely',
#  'account',
#  'actually',
#  'ad',
#  'add',
#  'addict',
#  'advice',
#  'afternoon',
#  'age',
#  'ago',
#  'agree',
#  'ah',
#  'ahh',
#  'aint',
#  'airport',
#  'album',
#  'alex',
#  'alive',
#  'almost',
#  'alone',
#  'along',
#  'alot',
#  'already',
#  'alright',
#  'also',
#  'always',
#  'amaze',
#  'angel',
#  'annoy',
#  'another',
#  'answer',
#  'anyone',
#  'anything',
#  'anyway',
#  'apparently',
#  'apple',
#  'application',
#  'appreciate',
#  'around',
#  'arrive',
#  'art',
#  'ask',
#  'asleep',
#  'australia',
#  'avatar',
#  'aw',
#  'award',
#  'away',
#  'awesome',
#  'aww',
#  'babe',
#  'baby',
#  'back',
#  'back work',
#  'background',
#  'bad',
#  'bag',
#  'bake',
#  'band',
#  'bar',
#  'bath',
#  'bbq',
#  'bday',
#  'beach',
#  'bear',
#  'beat',
#  'beautiful',
#  'beautiful day',
#  'become',
#  'bed',
#  'beer',
#  'begin',
#  'behind',
#  'believe',
#  'best',
#  'best friend',
#  'bet',
#  'better',
#  'bf',
#  'big',
#  'bike',
#  'birthday',
#  'bitch',
#  'bite',
#  'black',
#  'blast',
#  'bless',
#  'blog',
#  'blood',
#  'blue',
#  'boo',
#  'book',
#  'bore',
#  'bos',
#  'bottle',
#  'bout',
#  'box',
#  'boy',
#  'boyfriend',
#  'brain',
#  'brand',
#  'break',
#  'breakfast',
#  'bright',
#  'brilliant',
#  'bring',
#  'bro',
#  'brother',
#  'btw',
#  'buddy',
#  'bug',
#  'build',
#  'burn',
#  'bus',
#  'business',
#  'busy',
#  'button',
#  'buy',
#  'bye',
#  'cake',
#  'call',
#  'camera',
#  'camp',
#  'cant',
#  'cant wait',
#  'car',
#  'card',
#  'care',
#  'case',
#  'cast',
#  'cat',
#  'catch',
#  'cause',
#  'cd',
#  'celebrate',
#  'chance',
#  'change',
#  'chat',
#  'check',
#  'cheer',
#  'cheese',
#  'chicken',
#  'chill',
#  'chillin',
#  'chocolate',
#  'choice',
#  'church',
#  'city',
#  'class',
#  'classic',
#  'clean',
#  'clear',
#  'click',
#  'client',
#  'close',
#  'closer',
#  'club',
#  'coast',
#  'coffee',
#  'cold',
#  'college',
#  'color',
#  'colour',
#  'come',
#  'come back',
#  'come home',
#  'comment',
#  'company',
#  'complain',
#  'complete',
#  'completely',
#  'computer',
#  'concert',
#  'congrats',
#  'congratulation',
#  'consider',
#  'cook',
#  'cooky',
#  'cool',
#  'could',
#  'count',
#  'country',
#  'couple',
#  'course',
#  'cousin',
#  'cover',
#  'crazy',
#  'cream',
#  'create',
#  'cross',
#  'cry',
#  'cup',
#  'currently',
#  'cut',
#  'cute',
#  'cuz',
#  'dad',
#  'daddy',
#  'damn',
#  'dance',
#  'dark',
#  'date',
#  'daughter',
#  'day',
#  'day get',
#  'day school',
#  'day today',
#  'day work',
#  'de',
#  'dear',
#  'decide',
#  'def',
#  'definitely',
#  'delicious',
#  'deserve',
#  'design',
#  'didnt',
#  'different',
#  'dinner',
#  'disney',
#  'dm',
#  'doctor',
#  'dog',
#  'doll',
#  'dont',
#  'download',
#  'draw',
#  'dream',
#  'dress',
#  'drink',
#  'drive',
#  'drop',
#  'dude',
#  'dunno',
#  'dvd',
#  'ear',
#  'earlier',
#  'early',
#  'easier',
#  'east',
#  'easy',
#  'eat',
#  'egg',
#  'eh',
#  'either',
#  'el',
#  'else',
#  'email',
#  'end',
#  'english',
#  'enjoy',
#  'enough',
#  'episode',
#  'especially',
#  'even',
#  'event',
#  'ever',
#  'every',
#  'everybody',
#  'everyday',
#  'everyone',
#  'everything',
#  'exactly',
#  'exam',
#  'excellent',
#  'excite',
#  'excuse',
#  'expect',
#  'experience',
#  'extra',
#  'eye',
#  'face',
#  'facebook',
#  'fact',
#  'fail',
#  'fair',
#  'fall',
#  'fam',
#  'family',
#  'fan',
#  'fantastic',
#  'far',
#  'fast',
#  'fav',
#  'favorite',
#  'favourite',
#  'fb',
#  'feature',
#  'fee',
#  'feel',
#  'feel better',
#  'feel good',
#  'feel like',
#  'fight',
#  'figure',
#  'fill',
#  'film',
#  'final',
#  'finally',
#  'finally get',
#  'find',
#  'fine',
#  'finger',
#  'finish',
#  'fire',
#  'first',
#  'first day',
#  'first time',
#  'fish',
#  'fit',
#  'fix',
#  'flight',
#  'fly',
#  'folk',
#  'follow',
#  'follower',
#  'food',
#  'foot',
#  'forever',
#  'forget',
#  'form',
#  'forward',
#  'free',
#  'fresh',
#  'friday',
#  'friend',
#  'front',
#  'fuck',
#  'full',
#  'fun',
#  'funny',
#  'future',
#  'game',
#  'garden',
#  'geek',
#  'german',
#  'get',
#  'get back',
#  'get better',
#  'get follower',
#  'get home',
#  'get love',
#  'get new',
#  'get ready',
#  'get twitter',
#  'gettin',
#  'gift',
#  'gig',
#  'girl',
#  'give',
#  'glad',
#  'glad like',
#  'go',
#  'go back',
#  'go bed',
#  'go get',
#  'go go',
#  'go make',
#  'go see',
#  'go sleep',
#  'go watch',
#  'go well',
#  'go work',
#  'god',
#  'goin',
#  'good',
#  'good day',
#  'good idea',
#  'good luck',
#  'good morning',
#  'good night',
#  'good thing',
#  'good time',
#  'goodness',
#  'goodnight',
#  'google',
#  'gorgeous',
#  'gosh',
#  'graduation',
#  'great',
#  'great day',
#  'great time',
#  'green',
#  'grow',
#  'guess',
#  'guitar',
#  'guy',
#  'gym',
#  'ha',
#  'hah',
#  'haha',
#  'hahah',
#  'hahaha',
#  'hahahaha',
#  'hair',
#  'half',
#  'hand',
#  'hang',
#  'hangover',
#  'hannah',
#  'happen',
#  'happy',
#  'happy bday',
#  'happy birthday',
#  'hard',
#  'hat',
#  'hate',
#  'head',
#  'hear',
#  'heart',
#  'hehe',
#  'hehehe',
#  'hell',
#  'hello',
#  'help',
#  'hey',
#  'hi',
#  'high',
#  'hilarious',
#  'hill',
#  'hit',
#  'hmm',
#  'hold',
#  'holiday',
#  'home',
#  'homework',
#  'honey',
#  'hoo',
#  'hop',
#  'hope',
#  'hopefully',
#  'horse',
#  'hot',
#  'hour',
#  'house',
#  'hows',
#  'hr',
#  'http',
#  'hug',
#  'huge',
#  'huh',
#  'hun',
#  'hungry',
#  'hurt',
#  'husband',
#  'ice',
#  'ice cream',
#  'idea',
#  'ill',
#  'ily',
#  'im',
#  'im go',
#  'imagine',
#  'indeed',
#  'info',
#  'inside',
#  'inspire',
#  'instead',
#  'interest',
#  'internet',
#  'interview',
#  'iphone',
#  'island',
#  'issue',
#  'itunes',
#  'ive',
#  'jack',
#  'jam',
#  'jealous',
#  'jk',
#  'job',
#  'john',
#  'join',
#  'joke',
#  'jonas',
#  'jonas brother',
#  'july',
#  'june',
#  'jus',
#  'keep',
#  'kevin',
#  'kick',
#  'kid',
#  'kill',
#  'kind',
#  'kinda',
#  'king',
#  'kiss',
#  'kitchen',
#  'know',
#  'know go',
#  'la',
#  'lady',
#  'land',
#  'laptop',
#  'last',
#  'last day',
#  'last night',
#  'late',
#  'later',
#  'laugh',
#  'law',
#  'lay',
#  'lazy',
#  'learn',
#  'least',
#  'leave',
#  'lesson',
#  'let',
#  'let go',
#  'let know',
#  'lie',
#  'life',
#  'light',
#  'like',
#  'lil',
#  'line',
#  'link',
#  'list',
#  'listen',
#  'little',
#  'live',
#  'lmao',
#  'load',
#  'lol',
#  'london',
#  'long',
#  'long day',
#  'long time',
#  'look',
#  'look forward',
#  'look good',
#  'look like',
#  'lose',
#  'lot',
#  'love',
#  'love new',
#  'love ya',
#  'lovely',
#  'lt',
#  'luck',
#  'lucky',
#  'lunch',
#  'luv',
#  'mad',
#  'magic',
#  'mail',
#  'make',
#  'make feel',
#  'make happy',
#  'mama',
#  'man',
#  'many',
#  'market',
#  'marry',
#  'match',
#  'mate',
#  'math',
#  'matt',
#  'matter',
#  'may',
#  'maybe',
#  'mean',
#  'medium',
#  'meet',
#  'men',
#  'mention',
#  'message',
#  'mi',
#  'michael',
#  'might',
#  'miley',
#  'milk',
#  'min',
#  'mind',
#  'mine',
#  'minute',
#  'miss',
#  'mix',
#  'mom',
#  'moment',
#  'mommy',
#  'monday',
#  'money',
#  'montana',
#  'month',
#  'mood',
#  'moon',
#  'mornin',
#  'morning',
#  'morning everyone',
#  'mostly',
#  'move',
#  'movie',
#  'mr',
#  'much',
#  'much better',
#  'mum',
#  'music',
#  'must',
#  'myspace',
#  'na',
#  'name',
#  'nap',
#  'near',
#  'nearly',
#  'need',
#  'never',
#  'new',
#  'new album',
#  'new phone',
#  'new song',
#  'new twitter',
#  'news',
#  'next',
#  'nice',
#  'nice day',
#  'nick',
#  'night',
#  'nite',
#  'no',
#  'nope',
#  'normal',
#  'note',
#  'nothing',
#  'notice',
#  'number',
#  'ny',
#  'nyc',
#  'office',
#  'officially',
#  'often',
#  'oh',
#  'oh yeah',
#  'ohh',
#  'ok',
#  'okay',
#  'old',
#  'omg',
#  'one',
#  'one day',
#  'online',
#  'ooh',
#  'oops',
#  'open',
#  'order',
#  'others',
#  'outside',
#  'outta',
#  'pack',
#  'page',
#  'pain',
#  'paint',
#  'pant',
#  'paris',
#  'park',
#  'part',
#  'party',
#  'pas',
#  'past',
#  'pay',
#  'peace',
#  'peep',
#  'people',
#  'perfect',
#  'perhaps',
#  'person',
#  'peter',
#  'philippine',
#  'phone',
#  'photo',
#  'pic',
#  'pick',
#  'picture',
#  'pink',
#  'pizza',
#  'place',
#  'plan',
#  'play',
#  'please',
#  'pleasure',
#  'plus',
#  'pm',
#  'point',
#  'pool',
#  'poor',
#  'pop',
#  'positive',
#  'possible',
#  'post',
#  'power',
#  'practice',
#  'pray',
#  'prefer',
#  'prepare',
#  'pretty',
#  'price',
#  'probably',
#  'problem',
#  'productive',
#  'profile',
#  'program',
#  'project',
#  'promise',
#  'proud',
#  'puppy',
#  'put',
#  'question',
#  'quick',
#  'quiet',
#  'quite',
#  'quote',
#  'race',
#  'radio',
#  'rain',
#  'random',
#  'rather',
#  'read',
#  'ready',
#  'ready go',
#  'real',
#  'realize',
#  'really',
#  'really good',
#  'reason',
#  'recommend',
#  'record',
#  'red',
#  'relax',
#  'release',
#  'remember',
#  'remind',
#  'reply',
#  'rest',
#  'return',
#  'review',
#  'ride',
#  'right',
#  'ring',
#  'road',
#  'rock',
#  'roll',
#  'room',
#  'round',
#  'rule',
#  'run',
#  'sad',
#  'safe',
#  'saturday',
#  'save',
#  'saw',
#  'say',
#  'say hi',
#  'school',
#  'science',
#  'score',
#  'scream',
#  'search',
#  'season',
#  'second',
#  'secret',
#  'see',
#  'see ya',
#  'seem',
#  'seem like',
#  'sell',
#  'send',
#  'seriously',
#  'service',
#  'session',
#  'set',
#  'sex',
#  'sexy',
#  'shake',
#  'shall',
#  'share',
#  'shirt',
#  'shit',
#  'shoe',
#  'shoot',
#  'shop',
#  'short',
#  'shout',
#  'show',
#  'shower',
#  'shut',
#  'si',
#  'sick',
#  'side',
#  'sign',
#  'silly',
#  'sims',
#  'since',
#  'sing',
#  'single',
#  'sister',
#  'sit',
#  'site',
#  'sleep',
#  'sleepy',
#  'slow',
#  'small',
#  'smell',
#  'smile',
#  'so',
#  'social',
#  'somebody',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'son',
#  'song',
#  'soo',
#  'soon',
#  'sorry',
#  'sort',
#  'sound',
#  'sound like',
#  'space',
#  'speak',
#  'special',
#  'spell',
#  'spend',
#  'st',
#  'stand',
#  'star',
#  'starbucks',
#  'start',
#  'start day',
#  'state',
#  'status',
#  'stay',
#  'step',
#  'still',
#  'stop',
#  'store',
#  'storm',
#  'story',
#  'straight',
#  'strawberry',
#  'street',
#  'student',
#  'study',
#  'stuff',
#  'stupid',
#  'style',
#  'suck',
#  'suggestion',
#  'summer',
#  'sun',
#  'sunday',
#  'sunny',
#  'sunshine',
#  'super',
#  'support',
#  'suppose',
#  'sure',
#  'surprise',
#  'sweet',
#  'sweet dream',
#  'swim',
#  'take',
#  'take care',
#  'talk',
#  'tan',
#  'taste',
#  'tea',
#  'teach',
#  'team',
#  'tell',
#  'test',
#  'text',
#  'thank',
#  'thank god',
#  'thank much',
#  'thankyou',
#  'thanx',
#  'thats',
#  'thing',
#  'think',
#  'think go',
#  'think im',
#  'tho',
#  'though',
#  'three',
#  'throw',
#  'thursday',
#  'ticket',
#  'til',
#  'till',
#  'time',
#  'time go',
#  'tire',
#  'title',
#  'today',
#  'together',
#  'tom',
#  'tomorrow',
#  'tonight',
#  'tony',
#  'top',
#  'topic',
#  'totally',
#  'touch',
#  'tour',
#  'town',
#  'track',
#  'train',
#  'travel',
#  'treat',
#  'trend',
#  'trip',
#  'true',
#  'trust',
#  'try',
#  'try get',
#  'tuesday',
#  'tune',
#  'turn',
#  'tv',
#  'tweeps',
#  'tweet',
#  'tweeter',
#  'twilight',
#  'twit',
#  'twitter',
#  'two',
#  'type',
#  'ugh',
#  'uk',
#  'um',
#  'umm',
#  'understand',
#  'update',
#  'upload',
#  'use',
#  'vacation',
#  'vega',
#  'via',
#  'video',
#  'view',
#  'vip',
#  'visit',
#  'vote',
#  'wait',
#  'wait go',
#  'wait see',
#  'wake',
#  'walk',
#  'want',
#  'war',
#  'warm',
#  'wash',
#  'watch',
#  'watch tv',
#  'watchin',
#  'water',
#  'way',
#  'wear',
#  'weather',
#  'website',
#  'wed',
#  'wednesday',
#  'week',
#  'weekend',
#  'welcome',
#  'well',
#  'wen',
#  'west',
#  'what',
#  'whats',
#  'white',
#  'whole',
#  'wife',
#  'win',
#  'window',
#  'wine',
#  'wish',
#  'wish could',
#  'wish luck',
#  'wit',
#  'without',
#  'wo',
#  'woman',
#  'wonder',
#  'wonderful',
#  'wont',
#  'woo',
#  'woot',
#  'word',
#  'work',
#  'work today',
#  'world',
#  'worry',
#  'worth',
#  'would',
#  'would like',
#  ...]

# %%
first_million_clean_tags[0:1500]
# Out:
#                      title               artist  \
# 0                Killa Cam              Cam'ron
# 1               Can I Live                JAY-Z
# 2        Forgive Me Father             Fabolous
# 3             Down and Out              Cam'ron
# 4                   Fly In            Lil Wayne
# ...                    ...                  ...
# 1495             Dont Stop  Child Rebel Soldier
# 1496           Wild Horses   The Rolling Stones
# 1497  Thieves in the Night           Black Star
# 1498  Windows Media Player     Charles Hamilton
# 1499    The Road Not Taken         Robert Frost
#
#                                              clean_text  \
# 0     [killa, cam, killa, cam, cam, killa, cam, kill...
# 1     [yeah, hah, yeah, rocafella, we, invite, you, ...
# 2     [maybe, cause, im, eatin, and, these, bastard,...
# 3     [ugh, killa, baby, kanye, this, that, heron, f...
# 4     [so, they, ask, me, young, boy, what, you, gon...
# ...                                                 ...
# 1495  [ugh, what, explain, yourself, how, you, sound...
# 1496  [childhood, live, be, easy, to, do, the, thing...
# 1497  [yo, d, what, come, on, yeah, what, what, come...
# 1498  [somewhere, on, the, desktop, live, the, zip, ...
# 1499  [two, road, diverge, in, a, yellow, wood, and,...
#
#                                                    tags
# 0     [load, second, im, im, bout, hit, shit, world,...
# 1     [yeah, hah, yeah, you, you, know, well, sort, ...
# 2     [maybe, cause, im, like, you, see, cant, so, i...
# 3     [ugh, baby, huh, yeah, let, ugh, im, back, ugh...
# 4     [so, ask, young, boy, what, you, second, time,...
# ...                                                 ...
# 1495  [ugh, what, you, sound, like, know, youre, pla...
# 1496  [live, easy, thing, you, want, buy, you, lady,...
# 1497  [yo, what, come, yeah, what, what, come, yeah,...
# 1498  [live, next, pop, kid, let, kid, clear, you, s...
# 1499  [two, road, sorry, could, travel, one, long, s...
#
# [1500 rows x 4 columns]

# %%
all(word in first_million_clean_tags[0:1500] for word in words)

# %%
import pandas as pd
import pyarrow.feather as feather

# Load the DataFrame from the Feather file
first_million_clean_tags = feather.read_feather('first_million_clean_tags.feather')

# Define top words to check
top_words = ['last', 'feel', 'last night', 'issue', 'ear']

# Define the range of rows to filter
random_sample = first_million_clean_tags.sample(n=500) 

def any_top_word_in_tags(tags, top_words):
    """
    Check if any word in `top_words` is present in `tags`.
    Assumes `tags` is a list-like object (e.g., list or numpy array).
    """
    return any(word in tags for word in top_words)

# Apply boolean indexing to filter rows
filtered_df = random_sample[random_sample['tags'].apply(lambda tags: any_top_word_in_tags(tags, top_words))]

# Print the shape of the filtered DataFrame to verify
print(f"Filtered DataFrame shape: {filtered_df.shape}")
# Out:
# Filtered DataFrame shape: (194, 4)

# %%
filtered_df.he
# Out:
#                                 title                 artist  \
# 310261                    Ghetto Life                    DMX
# 356550                          Ridin           Classic & 86
# 373561                  Celebrate You  Steven Curtis Chapman
# 633567  Lost Connection With The Head              Showbread
# 178016    Clarissa Volume 1 Letter 12      Samuel Richardson
#
#                                                clean_text  \
# 310261  [nigga, say, im, bug, and, ask, me, whats, tha...
# 356550  [let, s, get, this, party, start, we, ll, get,...
# 373561  [im, no, stranger, to, your, gentle, reminder,...
# 633567  [oh, lord, im, sick, of, myself, id, rather, b...
# 178016  [miss, howe, to, miss, clarissa, harlowe, thur...
#
#                                                      tags
# 310261  [say, im, bug, ask, whats, shit, im, cause, wr...
# 356550  [let, get, party, start, get, crazy, tonight, ...
# 373561  [im, no, world, around, no, you, speak, word, ...
# 633567  [oh, im, sick, rather, im, help, mean, follow,...
# 178016  [miss, miss, thursday, morning, indeed, you, w...

# %% [markdown]
# ### IMPLEMENT LOGIC

# %% [markdown]
# # LOGIC OMPLETED FOR MUSIXMATCH FUNCTION

# %%
#import libraries

import pandas as pd
import pyarrow.feather as feather
import numpy as np


#load feather file
first_million_clean_tags = feather.read_feather('first_million_clean_tags.feather')


top_words = ['im', 'mean', 'kill', 'science', 'today']



def search_lyrics(top_words):
    
    #create lists of song details
    list_of_artists = []
    list_of_tracks = []
    list_of_lyrics = []

    #get a random sample of 500 songs:
    
    random_sample = first_million_clean_tags.sample(n=500) 
    
    def any_top_word_in_tags(tags, top_words):
        return any(word in tags for word in top_words)
    
    
    filtered_data = random_sample[random_sample['tags'].apply(lambda tags: any_top_word_in_tags(tags, top_words))]


    list_of_artists = filtered_data['artist'].tolist()
    list_of_tracks = filtered_data['title'].tolist()
    list_of_lyrics = filtered_data['clean_text'].tolist()

    #turn in dataframe
    new_lyrics_df = pd.DataFrame({
                        'Artist': list_of_artists,
                        'Track': list_of_tracks,
                        'Lyric_Snippet': list_of_lyrics})
    
    return new_lyrics_df

print(search_lyrics(['im', 'mean', 'kill', 'science', 'today']))
# Out:
#                Artist                                            Track  \
# 0            Dr. Hook                                         Loveline
# 1       Kristin Hersh                                   Vanishing Twin
# 2           Don Cisco                                 Just Like Mexico
# 3             Unwoman                                      Fugue Fugue
# 4     New Found Glory                                  Head Over Heels
# ..                ...                                              ...
# 280     George Strait              A Little Heaven’s Rubbing Off on Me
# 281        Soulsister                                          Changes
# 282     Doug E. Fresh                           Everybody Loves a Star
# 283  Jasmine Mulliken  Maria Edgeworth’s “Practical Education Chap. 1”
# 284           KRS-One                                  Down the Charts
#
#                                          Lyric_Snippet
# 0    [if, you, ever, need, me, call, me, on, your, ...
# 1    [i, feel, the, tug, of, war, i, fight, the, fi...
# 2    [you, want, to, know, why, i, ride, or, die, f...
# 3    [with, an, empty, heart, and, all, my, hope, w...
# 4    [i, want, to, be, with, you, alone, and, talk,...
# ..                                                 ...
# 280  [i, use, to, like, make, love, then, get, up, ...
# 281  [here, we, be, but, it, not, the, same, why, d...
# 282  [chorus, everybody, love, a, star, chill, will...
# 283  [toy, why, dont, you, play, with, your, playth...
# 284  [you, cant, still, worry, about, the, chart, p...
#
# [285 rows x 3 columns]

# %%
def join_lyrics(text):
    
    if isinstance(text, np.ndarray):
        
        list_of_strings = text.astype(str).tolist()
        
        return ' '.join(list_of_strings)
    
    return ''

# %%
result = first_million_clean_tags['clean_text'][0:5].apply(join_lyrics)

# %%
print(result)
# Out:
# 0    killa cam killa cam cam killa cam killa cam ki...
# 1    yeah hah yeah rocafella we invite you to somet...
# 2    maybe cause im eatin and these bastard fiend f...
# 3    ugh killa baby kanye this that heron flow huh ...
# 4    so they ask me young boy what you gon do the s...
# Name: clean_text, dtype: object
